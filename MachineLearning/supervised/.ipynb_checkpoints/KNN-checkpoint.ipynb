# %% [markdown]
# ### Regression Dataset
# We will create dataset using `make_regression` .
#
# Dataset will have :
# - 1000 samples (`n_samples`) ( number of rows )
# - 2 features (`n_features` ) ( number of feature columns )

# %%
from sklearn.datasets import make_regression

# %%
X , y = make_regression(n_samples=1000, n_features=2, random_state=42, bias = 5, noise = 1)

# %%
X.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %% [markdown]
# ### Splitting Dataset
#
# Let's split the dataset using `train_test_split` .
# - Training Data = 75%
# - Testing Data = 25%

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , random_state = 42 , test_size=0.25 )

# %%
X_train.shape
# Out:
# (750, 2)

# %%
y_train.shape
# Out:
# (750,)

# %% [markdown]
# ### Model Training
#
# We will train a KNN model for regression using `KNeighborsRegressor` from `sklearn.neighbors` .
#
# Also we will use value of K = 7 ( Model will determine prediction based on 7 nearest neighbors )
#
# **Note : Always Use _Odd_ value for K** ( eg. 1 , 3 , 5 , etc. )

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model = KNeighborsRegressor(n_neighbors=7)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %% [markdown]
# ### Prediction , Evaluation
#
# We will predict the values of y using `model.predict` .
#
# We will evaluate based on these metrics :
# - `Mean Squared Error`
# - `Mean Absolute Error`
# - `R2 Score`

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

# %%
mse = mean_squared_error(y_test , y_pred)
mae = mean_absolute_error(y_test , y_pred)
r2 = r2_score(y_test , y_pred)

# %%
print(f"Mean Square Error : {mse:4f}")
print(f"Mean Absolute Error : {mae:4f}")
print(f"R2 score : {r2}")
# Out:
# Mean Square Error : 12.245096
# Mean Absolute Error : 2.117060
# R2 score : 0.9917743366772478

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.7)
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.show()
